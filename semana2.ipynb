# %% [markdown]
# # Aplicação do conteúdo visto na segunda semana

# %% [markdown]
# ## Conteúdos abordados:
# ### - Thresholding, automatic thresholding, local thresholding
# ### - Gray level transformations
# ### - Image negatives
# ### - Logarithmic transformations
# ### - Piecewise transformations
# ### - Histogram processing and histogram equalization

# %%
import cv2 as cv
import matplotlib
import numpy as np
from matplotlib import pyplot as plt
from ipywidgets import interact, interactive, interact_manual

# %%
# Lê a imagem e transforma em gray scale
image = cv.imread('./Assets/meisje_met_de_parel.jpg')
image = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
plt.imshow(image, 'gray')

def threshold(thresh):
    global image
    global image_thresh
    th, image = cv.threshold(change, thresh, 255, cv.THRESH_BINARY)
    fig, axes = plt.subplots(1, 2, figsize=(12,16))
    axes[0].imshow(change, 'gray')
    axes[1].imshow(dst, 'gray')
